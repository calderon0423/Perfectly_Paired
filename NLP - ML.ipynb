# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import urllib, json
import string

## NLTK basics
import nltk
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from nltk.tokenize import RegexpTokenizer

## sklearn basics
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

## Decision trees
from sklearn import tree

## Random Forest
from sklearn.ensemble import RandomForestClassifier

## knn
from sklearn.neighbors import KNeighborsClassifier

## SVC
from sklearn.svm import SVC
from sklearn.metrics import classification_report

## kmeans
from sklearn.cluster import KMeans

## neural network
import tensorflow
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow import random

## grid search
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("Resources/winemag-data-130k-v2.csv")

variety_list = pd.read_csv("Resources/Wine_varieties.csv", index=False)

variety_list = variety_list.variety.tolist()

subset = df.loc[df['variety'].isin(variety_list)]

subset = subset[['country', 'description', 'points', 'province', 'variety']]

subset.head()
# Out:
#     country                                        description  points  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87
# 2        US  Tart and snappy, the flavors of lime flesh and...      87
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87
# 4        US  Much like the regular bottling from 2012, this...      87
#
#             province         variety
# 0  Sicily & Sardinia     White Blend
# 1              Douro  Portuguese Red
# 2             Oregon      Pinot Gris
# 3           Michigan        Riesling
# 4             Oregon      Pinot Noir

# %%
#Split reviews into words
tokenizer = nltk.RegexpTokenizer(r'\w+')
tokens = subset["description"].apply(tokenizer.tokenize)

#Remove useless stuff
stop_words = stopwords.words('english')
adj_list = []

for synset in list(wn.all_synsets(wn.ADJ)):
    s = synset.name()
    lemma = s.split('.')[0]
    adj_list.append(lemma)

for item in tokens:
    for r in item:
        if (r.lower() not in adj_list) and (r.lower() in stop_words): 
            item.remove(r)
            
#Add split text lists to df
subset["description_split"] = tokens

subset.to_csv('Resources/Wine_Reviews_ML.csv', index=False)

subset.head()
# Out:
#     country                                        description  points  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87
# 2        US  Tart and snappy, the flavors of lime flesh and...      87
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87
# 4        US  Much like the regular bottling from 2012, this...      87
#
#             province         variety  \
# 0  Sicily & Sardinia     White Blend
# 1              Douro  Portuguese Red
# 2             Oregon      Pinot Gris
# 3           Michigan        Riesling
# 4             Oregon      Pinot Noir
#
#                                    description_split
# 0  [Aromas, include, tropical, fruit, broom, brim...
# 1  [is, ripe, fruity, wine, is, smooth, still, st...
# 2  [Tart, snappy, flavors, lime, flesh, rind, dom...
# 3  [Pineapple, rind, lemon, pith, orange, blossom...
# 4  [Much, like, regular, bottling, 2012, comes, a...

# %%
descriptors = subset.description_split.tolist()

#Create empty dict
descriptors_dict = {}
temp_list = []

#Iterate!
for sublist in descriptors:
    temp_list.extend(sublist)

d = FreqDist(temp_list)
descriptors_dict = dict((k, v) for k, v in d.items() if (k.lower() in adj_list) and (k.lower() not in stop_words))

descriptors_dict
# Out:
# {'tropical': 3604,
#  'dried': 7773,
#  'expressive': 597,
#  'sage': 1748,
#  'brisk': 1887,
#  'ripe': 25293,
#  'fruity': 9193,
#  'smooth': 6566,
#  'still': 5302,
#  'structured': 5109,
#  'Firm': 673,
#  'filled': 505,
#  'juicy': 9120,
#  'red': 20745,
#  'drinkable': 827,
#  'better': 1552,
#  'snappy': 546,
#  'green': 9327,
#  'crisp': 11821,
#  'stainless': 687,
#  'orange': 5627,
#  'honey': 3982,
#  'astringent': 1304,
#  'Much': 61,
#  'like': 7762,
#  'regular': 356,
#  'rough': 711,
#  'tannic': 6254,
#  'earthy': 4420,
#  'herbal': 5911,
#  'good': 8707,
#  'hearty': 714,
#  'typical': 879,
#  'full': 14825,
#  'bodied': 11542,
#  'dark': 11113,
#  'fresh': 15909,
#  'bright': 9830,
#  'informal': 330,
#  'candied': 2337,
#  'white': 12545,
#  'savory': 4880,
#  'balanced': 8191,
#  'soft': 12179,
#  'dry': 15823,
#  'restrained': 1003,
#  'Balanced': 306,
#  'firm': 8547,
#  'much': 2870,
#  'Savory': 337,
#  'preserved': 151,
#  'elegant': 4753,
#  'sprightly': 237,
#  'great': 4697,
#  'Soft': 1453,
#  'supported': 615,
#  'complete': 502,
#  'strong': 2732,
#  'attractive': 3600,
#  'immediate': 367,
#  'tight': 4775,
#  'taut': 1029,
#  'mineral': 6296,
#  'layered': 2071,
#  'well': 13127,
#  'reduced': 243,
#  'chalky': 977,
#  'otherwise': 588,
#  'rich': 16226,
#  'black': 27907,
#  'whole': 788,
#  'dominated': 901,
#  'driven': 1856,
#  'vanilla': 10795,
#  'together': 2341,
#  'Astringent': 64,
#  'abrupt': 113,
#  'six': 768,
#  'cut': 2067,
#  'everyday': 707,
#  'approachable': 1171,
#  'distinctive': 480,
#  'toned': 926,
#  'racy': 1301,
#  'lean': 2249,
#  'easy': 4666,
#  'wide': 447,
#  'Baked': 309,
#  'balsamic': 940,
#  'braced': 51,
#  'compact': 683,
#  'set': 1363,
#  'peppery': 2322,
#  'respectable': 30,
#  'Raw': 81,
#  'direct': 519,
#  'simple': 3435,
#  'becoming': 155,
#  'apparent': 285,
#  'smoldering': 16,
#  'meaty': 1117,
#  'hot': 1202,
#  'Desiccated': 2,
#  'mint': 2478,
#  'top': 1342,
#  'forceful': 122,
#  'based': 1363,
#  'Red': 990,
#  'back': 1399,
#  'crushed': 3138,
#  'ready': 4715,
#  'Ripe': 2059,
#  'ample': 1293,
#  'toasted': 2856,
#  'dusty': 2084,
#  'sleek': 408,
#  'fair': 288,
#  'available': 209,
#  'aged': 2500,
#  'neutral': 730,
#  'Delicate': 403,
#  'sour': 2248,
#  'flat': 760,
#  'first': 2370,
#  'robust': 1054,
#  'wet': 1562,
#  'high': 3584,
#  'Small': 56,
#  'intense': 3445,
#  'smoky': 4000,
#  'Pretty': 428,
#  'yellow': 4183,
#  'stone': 3847,
#  'delicate': 2396,
#  'round': 3404,
#  'mature': 2725,
#  'scorched': 407,
#  'animal': 311,
#  'several': 770,
#  'residual': 837,
#  'straightforward': 1436,
#  'blessed': 12,
#  'cold': 273,
#  'laced': 901,
#  'light': 11013,
#  'open': 1819,
#  'base': 397,
#  'roast': 331,
#  'quality': 2023,
#  'clean': 5397,
#  'sharp': 1820,
#  'extended': 200,
#  'backed': 1461,
#  'wild': 3878,
#  'Made': 3107,
#  'similar': 356,
#  'New': 533,
#  'many': 1493,
#  'unripe': 263,
#  'sweet': 12760,
#  'White': 311,
#  'mellow': 802,
#  'chunky': 1240,
#  'powdery': 90,
#  'warm': 2494,
#  'oily': 624,
#  'short': 1233,
#  'concentrated': 5938,
#  'cured': 623,
#  'bold': 2283,
#  'chewy': 1936,
#  'color': 4179,
#  'natural': 802,
#  'made': 3866,
#  'organic': 336,
#  'nice': 2487,
#  'one': 4954,
#  'stiff': 229,
#  'plus': 706,
#  'instant': 42,
#  'Asian': 780,
#  'modest': 891,
#  'Right': 207,
#  'starting': 316,
#  'caramel': 2424,
#  'graceful': 173,
#  'eccentric': 46,
#  'fried': 145,
#  'pretty': 2790,
#  'bearing': 95,
#  'fleshy': 1219,
#  'grassy': 660,
#  'glazed': 84,
#  'chicken': 444,
#  'generous': 3255,
#  'gentle': 1094,
#  'different': 527,
#  'hard': 2351,
#  'leafy': 719,
#  'long': 6147,
#  'raw': 1300,
#  'Fruity': 373,
#  'herbaceous': 660,
#  'fine': 6906,
#  'textured': 2914,
#  'pink': 1691,
#  'blue': 1717,
#  'weighty': 422,
#  'creamy': 5465,
#  'medium': 6047,
#  'brown': 1012,
#  'authentic': 68,
#  'Syrupy': 19,
#  'dense': 5009,
#  'indeterminate': 5,
#  'easygoing': 881,
#  'brooding': 741,
#  'Best': 844,
#  'suited': 75,
#  'fat': 527,
#  'yeasty': 870,
#  'intriguing': 855,
#  'salt': 575,
#  'golden': 699,
#  'broad': 1034,
#  'usual': 241,
#  'rounded': 2686,
#  'young': 4166,
#  'disjointed': 159,
#  'volatile': 135,
#  'woody': 944,
#  'deep': 2234,
#  'packed': 1836,
#  'cooperative': 79,
#  'canned': 165,
#  'Big': 621,
#  'Full': 1224,
#  'gravelly': 111,
#  'pleasant': 1541,
#  'skinned': 905,
#  'game': 899,
#  'Juicy': 641,
#  'designate': 311,
#  'wrapped': 929,
#  'overall': 1299,
#  'equal': 516,
#  'small': 1182,
#  'integrated': 1958,
#  'Earthy': 766,
#  'pulpy': 179,
#  'intensified': 22,
#  'overripe': 742,
#  'tangerine': 2166,
#  'Similar': 53,
#  'undemanding': 2,
#  'accessible': 797,
#  'front': 1470,
#  'center': 692,
#  'heavy': 2173,
#  'choppy': 394,
#  'Herbal': 353,
#  'salty': 942,
#  'forced': 99,
#  'Bland': 31,
#  'weak': 86,
#  'side': 2180,
#  'free': 44,
#  'known': 652,
#  'perfect': 1097,
#  'Pale': 171,
#  'healthy': 420,
#  'Racy': 137,
#  'Vibrant': 256,
#  'Softened': 11,
#  'dotted': 80,
#  'baked': 3200,
#  'Subdued': 140,
#  'French': 2220,
#  'chopped': 838,
#  'shy': 546,
#  'enjoyable': 719,
#  'close': 2122,
#  'perceptible': 44,
#  'coastal': 409,
#  'Together': 103,
#  'brawny': 390,
#  'footed': 216,
#  'charming': 260,
#  'baking': 2469,
#  'potential': 1534,
#  'finished': 304,
#  'pressed': 944,
#  'marked': 769,
#  'linear': 850,
#  'assertive': 755,
#  'Even': 225,
#  'later': 240,
#  'five': 953,
#  'plummy': 390,
#  'Fresh': 1586,
#  'smoked': 1155,
#  'Rich': 1224,
#  'Dusty': 448,
#  'citric': 653,
#  'mild': 1317,
#  'acidic': 1482,
#  'acid': 1268,
#  'subtle': 2222,
#  'inviting': 909,
#  'polished': 2073,
#  'ginger': 813,
#  'solid': 3509,
#  'heady': 543,
#  'substantial': 522,
#  'fragrant': 1655,
#  'saline': 375,
#  'Dried': 310,
#  'rose': 2485,
#  'steely': 1113,
#  'Pink': 75,
#  'woven': 231,
#  'standard': 472,
#  'complex': 4515,
#  'Medium': 789,
#  'gold': 450,
#  'Complex': 215,
#  'vibrant': 2283,
#  'focused': 1350,
#  'defined': 510,
#  'backward': 6,
#  'given': 886,
#  'Turkish': 42,
#  'little': 3910,
#  'mid': 349,
#  'new': 4073,
#  'potent': 330,
#  'huge': 482,
#  'negotiable': 10,
#  'two': 1749,
#  'third': 290,
#  'framed': 1233,
#  'sophisticated': 604,
#  'Smaller': 3,
#  'lovely': 1885,
#  'best': 2870,
#  'powerful': 2650,
#  'super': 441,
#  'Mid': 15,
#  'floral': 3383,
#  'Attractive': 229,
#  'Strong': 190,
#  'precise': 273,
#  'Compelling': 21,
#  'Refined': 30,
#  'leading': 628,
#  'big': 3502,
#  'olive': 1649,
#  'tough': 829,
#  'three': 858,
#  'subdued': 715,
#  'ten': 59,
#  'minute': 30,
#  'developed': 181,
#  'dominant': 546,
#  'beginning': 328,
#  'interesting': 1251,
#  'Well': 292,
#  'Intense': 360,
#  'Crisp': 1012,
#  'Taut': 65,
#  'impressive': 1753,
#  'ago': 117,
#  'improving': 30,
#  'trying': 83,
#  'early': 488,
#  'primary': 439,
#  'least': 1327,
#  'Imported': 231,
#  'essential': 63,
#  'austere': 851,
#  'Beautiful': 131,
#  'Packed': 143,
#  'following': 91,
#  'surprising': 231,
#  'hefty': 199,
#  'beautiful': 1435,
#  'refined': 1094,
#  'cleansing': 244,
#  'half': 578,
#  'Broad': 84,
#  'bone': 820,
#  'Thick': 210,
#  'higher': 247,
#  'Cooked': 25,
#  'planted': 693,
#  'longtime': 109,
#  'bay': 404,
#  'promising': 269,
#  'funded': 1,
#  'cooked': 382,
#  'Black': 1076,
#  'lush': 2310,
#  'sexy': 102,
#  'pristine': 355,
#  'enhanced': 363,
#  'burned': 43,
#  'revealing': 232,
#  'lavender': 752,
#  'developing': 638,
#  'second': 540,
#  'tactile': 28,
#  'Dark': 1273,
#  'thick': 2144,
#  'bitter': 3205,
#  'massive': 345,
#  'gooey': 34,
#  'purple': 1310,
#  'Judicious': 9,
#  'energetic': 165,
#  'Loud': 11,
#  'moderate': 810,
#  'Brown': 52,
#  'exciting': 219,
#  'lavish': 198,
#  'electrifying': 7,
#  'exceptional': 261,
#  'High': 377,
#  'south': 241,
#  'Still': 677,
#  'Low': 50,
#  'excess': 61,
#  'even': 2177,
#  'sizzling': 82,
#  'charitable': 8,
#  'blackened': 236,
#  'Chilean': 261,
#  'patented': 26,
#  'Dry': 1377,
#  'compelling': 564,
#  'last': 585,
#  'north': 255,
#  'rocky': 168,
#  'alluvial': 2,
#  'multiple': 99,
#  'crystalline': 95,
#  'invigorating': 222,
#  'harmonious': 352,
#  'turned': 379,
#  'gorgeous': 603,
#  'forward': 2463,
#  'true': 533,
#  'appealing': 1184,
#  'Good': 767,
#  'enduring': 77,
#  'mountainous': 65,
#  'Alto': 33,
#  'unusual': 784,
#  'magnetic': 12,
#  'boring': 16,
#  'continuous': 16,
#  'steady': 267,
#  'lively': 4089,
#  'piquant': 131,
#  'moonless': 7,
#  'right': 2225,
#  'old': 2012,
#  'edged': 346,
#  'Loaded': 54,
#  'exotic': 2247,
#  'genuine': 92,
#  'pure': 2183,
#  'joined': 187,
#  'Composed': 35,
#  'borderline': 84,
#  'elevated': 125,
#  'seeing': 16,
#  'excellent': 1112,
#  'saturated': 465,
#  'Clean': 363,
#  'honest': 199,
#  'Overall': 318,
#  'rubber': 692,
#  'muscular': 388,
#  'blended': 675,
#  'perfumed': 2642,
#  'traditional': 444,
#  'popular': 314,
#  'tonic': 270,
#  'decadent': 291,
#  'eastern': 147,
#  'persistent': 673,
#  'Alpine': 124,
#  'pleasing': 833,
#  'Smooth': 626,
#  'Ready': 467,
#  'legendary': 52,
#  'flowery': 107,
#  'oxidative': 75,
#  'Smoked': 33,
#  'built': 502,
#  'level': 973,
#  'understated': 150,
#  'True': 66,
#  'flinty': 310,
#  'Ample': 81,
#  'Intriguing': 75,
#  'adhesive': 25,
#  'Mellow': 59,
#  'nonspecific': 13,
#  'Salty': 112,
#  'wound': 806,
#  'likely': 678,
#  'Opened': 2,
#  'emerging': 116,
#  'seasoned': 192,
#  'overdone': 201,
#  'Mediterranean': 634,
#  'aging': 5334,
#  'another': 1128,
#  'Pithy': 70,
#  'beloved': 23,
#  'Northern': 66,
#  'delightful': 303,
#  'energizing': 110,
#  'Chopped': 13,
#  'Bright': 1150,
#  'jagged': 120,
#  'extreme': 286,
#  'expressed': 73,
#  'cool': 1913,
#  'opening': 542,
#  'clear': 342,
#  'southern': 499,
#  'Orange': 195,
#  'Meaty': 100,
#  'rubbery': 886,
#  'sound': 164,
#  'tasty': 927,
#  'woodsy': 122,
#  'imperceptible': 7,
#  'odd': 162,
#  'acetic': 4,
#  'pungent': 379,
#  'atypical': 49,
#  'dirt': 57,
#  'Neutral': 57,
#  'past': 423,
#  'melted': 256,
#  'stirred': 10,
#  'shriveled': 19,
#  'faint': 336,
#  'amber': 111,
#  'Australian': 100,
#  'rugged': 335,
#  'Dominated': 132,
#  'used': 415,
#  'local': 256,
#  'touched': 442,
#  'modern': 701,
#  'sparkling': 846,
#  'earlier': 39,
#  'Simple': 382,
#  'admirable': 47,
#  'Tasty': 72,
#  'lesser': 46,
#  'Abundant': 23,
#  'Huge': 43,
#  'childish': 1,
#  'size': 211,
#  'polish': 311,
#  'Fine': 301,
#  'velvet': 323,
#  'superb': 259,
#  'Tannic': 108,
#  'Young': 241,
#  'minty': 987,
#  'every': 397,
#  'sturdy': 365,
#  'loaded': 823,
#  'bittersweet': 249,
#  'flavorful': 673,
#  'going': 1001,
#  'syrupy': 582,
#  'spare': 55,
#  'Golden': 346,
#  'Stone': 97,
#  'Lively': 273,
#  'far': 538,
#  'Measured': 10,
#  'four': 647,
#  'active': 16,
#  'thorough': 47,
#  'Italian': 485,
#  'northern': 375,
#  'Thai': 152,
#  'average': 162,
#  'real': 599,
#  'sufficient': 58,
#  'absolute': 47,
#  'Indian': 249,
#  'Otherwise': 75,
#  'eight': 240,
#  'uncommon': 54,
#  'aromatic': 2523,
#  'future': 573,
#  'stable': 42,
#  'closed': 565,
#  'oxidized': 258,
#  'minus': 9,
#  'near': 596,
#  'Deep': 379,
#  'welcoming': 136,
#  'friendly': 1191,
#  'classy': 265,
#  'obvious': 260,
#  'proper': 276,
#  'ephemeral': 24,
#  'Cool': 97,
#  'low': 1169,
#  'characteristic': 304,
#  'Sweet': 656,
#  'Fragrant': 275,
#  'Another': 180,
#  'Romanian': 27,
#  'unbeatable': 7,
#  'less': 799,
#  'formal': 12,
#  'Aged': 473,
#  'large': 319,
#  'braised': 67,
#  'upfront': 441,
#  'capped': 74,
#  'Honey': 144,
#  'Fiery': 21,
#  'Strange': 10,
#  'familiar': 198,
#  'flashy': 300,
#  'according': 28,
#  'Brut': 235,
#  'puff': 24,
#  'surrounded': 229,
#  'Snappy': 71,
#  'alone': 91,
#  'Extra': 100,
#  'bubbly': 298,
#  'cheerful': 202,
#  'foaming': 86,
#  'Opening': 80,
#  'Animal': 14,
#  'sugary': 588,
#  'Frosted': 1,
#  'unique': 466,
#  'kind': 367,
#  'bubbling': 50,
#  'harsh': 229,
#  'mentholated': 22,
#  'Light': 1635,
#  'breezy': 76,
#  'thin': 850,
#  'fleeting': 288,
#  'spoiled': 28,
#  'Plummy': 45,
#  'Funky': 71,
#  'vegetal': 495,
#  'Vegetal': 28,
#  'stale': 26,
#  'acceptable': 62,
#  'weird': 46,
#  'unbalanced': 127,
#  'mealy': 175,
#  'material': 17,
#  'delectable': 21,
#  'enormous': 185,
#  'excessive': 106,
#  'endless': 50,
#  'damp': 189,
#  'juxtaposed': 32,
#  'enlivened': 71,
#  'terrific': 231,
#  'stunning': 258,
#  'tilled': 531,
#  'colored': 950,
#  'Hungarian': 71,
#  'ethereal': 228,
#  'cloying': 325,
#  'Russian': 245,
#  'memorable': 171,
#  'honeyed': 1112,
#  'historic': 237,
#  'apt': 19,
#  'Tropical': 198,
#  'falling': 42,
#  'Grand': 275,
#  'poised': 361,
#  'stylish': 465,
#  'allied': 115,
#  'underlying': 513,
#  'Elegant': 264,
#  'rolled': 25,
#  'fabled': 5,
#  'jammed': 4,
#  'selected': 102,
#  'liquid': 105,
#  'lemony': 1233,
#  'lay': 49,
#  'due': 449,
#  'vital': 163,
#  'worth': 459,
#  'broiled': 46,
#  'nutty': 593,
#  'Mint': 103,
#  'found': 348,
#  'lightweight': 225,
#  'Fleshy': 142,
#  'comfortable': 95,
#  'aggressive': 366,
#  'alive': 163,
#  'Long': 255,
#  'Old': 263,
#  'bracing': 878,
#  'lacking': 334,
#  'versatile': 257,
#  'Oriental': 23,
#  'One': 672,
#  'consistent': 250,
#  'Bone': 132,
#  'Choice': 25,
#  'buttery': 894,
#  'contrary': 7,
#  'current': 135,
#  'Peppery': 142,
#  'sure': 292,
#  'Decent': 47,
#  'done': 339,
#  'cardboard': 12,
#  'Tonic': 14,
#  'transparent': 45,
#  'watery': 229,
#  'grapey': 132,
#  'driving': 188,
#  'timid': 13,
#  'ordinary': 82,
#  'Nice': 231,
#  'funky': 499,
#  'home': 313,
#  'flaccid': 7,
#  'Indonesian': 3,
#  'playful': 163,
#  'lazy': 35,
#  'vivid': 551,
#  'final': 853,
#  'softened': 267,
#  'fifth': 35,
#  'Drinkable': 59,
#  'go': 1368,
#  'late': 943,
#  'reserved': 337,
#  'lost': 155,
#  'distinct': 354,
#  'serious': 949,
#  'ideal': 338,
#  'elastic': 14,
#  'warming': 104,
#  'alluring': 354,
#  'Yellow': 177,
#  'Smoky': 397,
#  'concrete': 126,
#  'shaped': 113,
#  'appetizing': 548,
#  'Creamy': 296,
#  'Blended': 250,
#  'seamless': 253,
#  'scattered': 50,
#  'Tender': 25,
#  'Fringed': 1,
#  'bare': 17,
#  'coated': 79,
#  'decent': 473,
#  'Behind': 61,
#  'exterior': 38,
#  'secondary': 217,
#  'thrilling': 59,
#  'marvelous': 34,
#  'remarkable': 172,
#  'Dense': 391,
#  'running': 208,
#  'pat': 16,
#  'left': 168,
#  'throated': 10,
#  'funny': 4,
#  'Awkward': 10,
#  'Tuscan': 224,
#  'superior': 46,
#  'must': 110,
#  'Bulky': 14,
#  'middle': 374,
#  'fatty': 93,
#  'Grave': 2,
#  'extra': 1101,
#  'stellar': 102,
#  'redolent': 311,
#  'Mild': 159,
#  'basic': 833,
#  'cutting': 315,
#  'welcome': 327,
#  'Three': 65,
#  'tame': 128,
#  'blowsy': 42,
#  'yielding': 253,
#  'grating': 133,
#  'reflecting': 50,
#  'abbreviated': 30,
#  'growing': 184,
#  'tense': 379,
#  'searing': 95,
#  'nervy': 363,
#  'uplifted': 41,
#  'youthful': 800,
#  'Chewy': 100,
#  'glorious': 64,
#  'owned': 324,
#  'Premier': 104,
#  'Effusive': 8,
#  'straw': 194,
#  'suitable': 34,
#  'rush': 32,
#  'effervescent': 69,
#  'pithy': 637,
#  'iconic': 102,
#  'sought': 32,
#  'Westside': 52,
#  'overpowering': 161,
#  'flush': 182,
#  'native': 351,
#  'Green': 367,
#  'opened': 101,
#  'present': 574,
#  'powered': 210,
#  'westernmost': 9,
#  'gamey': 32,
#  'musky': 129,
#  'Heady': 114,
#  'paired': 184,
#  'self': 22,
#  'westerly': 2,
#  'Natural': 12,
#  'Serious': 30,
#  'salted': 160,
#  'mighty': 53,
#  'Aging': 57,
#  'ranging': 112,
#  'premium': 24,
#  'Welcoming': 10,
#  'boned': 145,
#  'manageable': 29,
#  'Generous': 158,
#  'numerous': 14,
#  'soothing': 107,
#  'opaque': 79,
#  'beguiling': 99,
#  'unlikely': 70,
#  'seductive': 417,
#  'rare': 477,
#  'boisterous': 103,
#  'unexpected': 67,
#  'loud': 128,
#  'handed': 77,
#  'located': 130,
#  'inland': 52,
#  'pale': 607,
#  'major': 133,
#  'Two': 125,
#  'plentiful': 86,
#  'diffuse': 38,
#  'slender': 597,
#  'Easy': 314,
#  'Purple': 59,
#  'dressed': 32,
#  'deft': 142,
#  'cohesive': 33,
#  'behind': 586,
#  'general': 98,
#  'feathery': 61,
#  'matched': 208,
#  'labeled': 213,
#  'sappy': 181,
#  'Hard': 249,
#  'possible': 179,
#  'dynamic': 140,
#  'Four': 29,
#  'fiery': 158,
#  'jarring': 20,
#  'thrown': 62,
#  'attenuated': 22,
#  'intended': 41,
#  'Yeasty': 135,
#  'hidden': 75,
#  'joyful': 42,
#  'chief': 41,
#  'Subtle': 334,
#  'gingery': 34,
#  'amazing': 145,
#  'topped': 190,
#  'controversial': 12,
#  'polar': 5,
#  'straight': 277,
#  'scented': 464,
#  'drenched': 87,
#  'mere': 77,
#  'definite': 146,
#  'fantastic': 150,
#  'combined': 147,
#  'detailed': 193,
#  'Superior': 50,
#  'exhilarating': 23,
#  'contrasting': 63,
#  'Cutting': 17,
#  'exalted': 3,
#  'awkward': 173,
#  'waiting': 147,
#  'challenging': 134,
#  'Based': 137,
#  'Western': 19,
#  'Reserved': 37,
#  'laid': 106,
#  'expansive': 201,
#  'abundant': 318,
#  'reticent': 85,
#  'recent': 154,
#  'Perfumed': 238,
#  'loamy': 256,
#  'virgin': 6,
#  'seedless': 4,
#  'exuberant': 364,
#  'Virgin': 2,
#  'alpine': 83,
#  'chilly': 68,
#  'Distinctive': 18,
#  'Brooding': 79,
#  'shaded': 57,
#  'Straw': 13,
#  'seared': 155,
#  'superfine': 13,
#  'brash': 46,
#  'slow': 83,
#  'supportive': 140,
#  'mannered': 33,
#  'Rounded': 168,
#  'surly': 3,
#  'coiled': 83,
#  'Floral': 399,
#  'Stainless': 39,
#  'Alluring': 103,
#  'worldwide': 7,
#  'soupy': 126,
#  'Mushy': 5,
#  'Angular': 19,
#  'powdered': 264,
#  'Initial': 102,
#  'correct': 198,
#  'missing': 161,
#  'Chunky': 123,
#  'Oily': 53,
#  'hollow': 173,
#  'suggestive': 118,
#  'edgy': 479,
#  'related': 111,
#  'sold': 36,
#  'cleanly': 48,
#  'dimensional': 483,
#  'elaborate': 114,
#  'Blowsy': 4,
#  'fit': 94,
#  'Pulpy': 7,
#  'composed': 308,
#  'excited': 10,
#  'described': 56,
#  'premier': 172,
#  'Southern': 126,
#  'derived': 126,
#  'meek': 7,
#  'looking': 156,
#  'brief': 66,
#  'pointed': 122,
#  'Round': 314,
#  'special': 286,
#  'outright': 40,
#  'expected': 189,
#  'competent': 28,
#  'intricate': 124,
#  'Powerful': 194,
#  'prime': 197,
#  'previous': 192,
#  'paid': 9,
#  'tempered': 158,
#  'single': 1236,
#  'heated': 5,
#  'particular': 172,
#  'Due': 9,
#  'closing': 40,
#  ...}

# %%
subset = subset[['country', 'description', 'points', 'province', 'variety', 'description_split']]

for key in descriptors_dict:
    subset[key] = 0

for key in descriptors_dict:
    for index, row in subset.iterrows():
        subset[key][index] += subset['description_split'][index].count(key)
        
# test['Aromas'][0] += test['description_split'][0].count('Aromas')
#     subset[key] = subset['description_split'].count(key)
# Out:
# /Users/richagautam/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/richagautam/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
subset
# Out:
# 0     1
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    0
# 96    0
# 97    0
# 98    0
# 99    0
# Name: Aromas, Length: 100, dtype: int64

# %%
# Set features. This will also be used as your x values.
X = subset.drop(["description", "variety"], axis=1)
y = subset["variety"]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

X_train.head()
# Out:
#           country  points            province  \
# 56921       Italy      87  Northeastern Italy
# 7894       France      84    Southwest France
# 24745       Chile      85    Cachapoal Valley
# 9828    Australia      89     South Australia
# 124193    Austria      94              Wachau
#
#                                         description_split
# 56921   [Moscato, Giallo, remarkable, ability, appeari...
# 7894    [is, typically, light, fruity, wine, Gascony, ...
# 24745   [Sharp, aromas, prickly, red, fruits, barrel, ...
# 9828    [Cassis, chocolate, notes, dominate, there, en...
# 124193  [nose, opens, totally, tangy, note, lemon, zes...

# %%
# Out:
# {'remarkable': 130,
#  'sweet': 9596,
#  'honey': 2970,
#  'yellow': 3148,
#  'rose': 1890,
#  'dry': 11721,
#  'polished': 1550,
#  'clean': 4068,
#  'crisp': 8827,
#  'close': 1634,
#  'light': 8269,
#  'fruity': 6913,
#  'fresh': 11912,
#  'green': 7039,
#  'Sharp': 118,
#  'red': 15621,
#  'lively': 3063,
#  'earthy': 3298,
#  'minty': 741,
#  'unresolved': 26,
#  'like': 5820,
#  'framed': 922,
#  'firm': 6389,
#  'dusty': 1566,
#  'long': 4665,
#  'Multiple': 5,
#  'U': 42,
#  'similar': 282,
#  'generous': 2454,
#  'fleshy': 929,
#  'juicy': 6748,
#  'orange': 4232,
#  'tangerine': 1585,
#  'streamlined': 255,
#  'countless': 5,
#  'concentrated': 4424,
#  'brisk': 1410,
#  'ripe': 19047,
#  'ultimate': 23,
#  'Crisp': 712,
#  'pink': 1239,
#  'Energizing': 12,
#  'pristine': 267,
#  'Made': 2266,
#  'Tuscan': 152,
#  'dried': 5777,
#  'candied': 1723,
#  'toasted': 2142,
#  'seasoned': 148,
#  'one': 3682,
#  'chalky': 745,
#  'right': 1678,
#  'Smoky': 295,
#  'powerful': 2004,
#  'soft': 9104,
#  'black': 20760,
#  'full': 11173,
#  'bodied': 8612,
#  'becoming': 115,
#  'back': 1087,
#  'straightforward': 1087,
#  'Bright': 864,
#  'dark': 8264,
#  'dense': 3740,
#  'linear': 645,
#  'pretty': 2078,
#  'kind': 278,
#  'hearty': 528,
#  'woody': 703,
#  'aging': 4034,
#  'quality': 1534,
#  'Dense': 281,
#  'smooth': 4978,
#  'rich': 12153,
#  'gorgeous': 434,
#  'redolent': 242,
#  'moderate': 596,
#  'half': 422,
#  'new': 3081,
#  'herbal': 4473,
#  'olive': 1234,
#  'wrapped': 707,
#  'baking': 1863,
#  'balanced': 6172,
#  'harmonious': 263,
#  'bright': 7408,
#  'white': 9463,
#  'stone': 2896,
#  'vanilla': 8130,
#  'promising': 212,
#  'still': 3955,
#  'opening': 421,
#  'perfumed': 1981,
#  'late': 696,
#  'French': 1698,
#  'Thick': 163,
#  'driven': 1396,
#  'savory': 3673,
#  'flat': 562,
#  'buttery': 681,
#  'sugary': 428,
#  'rank': 15,
#  'higher': 190,
#  'southern': 380,
#  'creamy': 4101,
#  'warm': 1853,
#  'wild': 2945,
#  'attractive': 2677,
#  'unique': 365,
#  'square': 18,
#  'based': 1046,
#  'secondary': 178,
#  'crushed': 2298,
#  'mineral': 4691,
#  'elegant': 3600,
#  'animal': 241,
#  'unpleasant': 40,
#  'mature': 2038,
#  'overripe': 542,
#  'balsamic': 698,
#  'astringent': 974,
#  'pickled': 158,
#  'front': 1122,
#  'Lemony': 58,
#  'lemony': 915,
#  'stirring': 23,
#  'distant': 75,
#  'pinched': 81,
#  'high': 2671,
#  'citric': 496,
#  'acid': 951,
#  'refined': 808,
#  'raw': 970,
#  'good': 6572,
#  'round': 2540,
#  'pulpy': 145,
#  'bitter': 2429,
#  'big': 2632,
#  'afloat': 14,
#  'touched': 322,
#  'weighty': 306,
#  'Still': 514,
#  'youthful': 592,
#  'integrated': 1469,
#  'Super': 52,
#  'sour': 1736,
#  'vigorous': 79,
#  'better': 1158,
#  'alternative': 78,
#  'Dusty': 335,
#  'juxtaposed': 28,
#  'intense': 2581,
#  'complex': 3313,
#  'deep': 1672,
#  'five': 710,
#  'average': 120,
#  'purple': 981,
#  'set': 1032,
#  'young': 3150,
#  'pleasant': 1191,
#  'short': 957,
#  'best': 2167,
#  'several': 574,
#  'different': 383,
#  'stylish': 354,
#  'pure': 1629,
#  'lush': 1732,
#  'strange': 100,
#  'gold': 332,
#  'amber': 83,
#  'color': 3106,
#  'neutral': 539,
#  'wrong': 47,
#  'exotic': 1709,
#  'great': 3539,
#  'translucent': 39,
#  'fine': 5149,
#  'coastal': 302,
#  'terrific': 177,
#  'ready': 3486,
#  'tropical': 2741,
#  'aged': 1894,
#  'least': 987,
#  'welcome': 248,
#  'honeyed': 828,
#  'Nice': 180,
#  'side': 1642,
#  'Single': 12,
#  'tight': 3553,
#  'four': 495,
#  'large': 234,
#  'perfect': 821,
#  'subdued': 530,
#  'behind': 442,
#  'unusual': 583,
#  'primary': 314,
#  'major': 104,
#  'severe': 115,
#  'austere': 618,
#  'much': 2135,
#  'Serviceable': 1,
#  'chilly': 51,
#  'cool': 1440,
#  'Russian': 195,
#  'unripe': 188,
#  'mint': 1885,
#  'game': 673,
#  'Reflecting': 36,
#  'forward': 1838,
#  'solid': 2615,
#  'lacking': 264,
#  'robust': 804,
#  'supportive': 101,
#  'mild': 986,
#  'Otherwise': 58,
#  'charming': 184,
#  'wet': 1163,
#  'marred': 18,
#  'overall': 979,
#  'little': 2958,
#  'smoky': 2972,
#  'racy': 947,
#  'tartaric': 79,
#  'bold': 1712,
#  'shallow': 21,
#  'Generic': 61,
#  'baked': 2382,
#  'local': 192,
#  'cut': 1556,
#  'Full': 914,
#  'ample': 978,
#  'profound': 47,
#  'irresistible': 93,
#  'compact': 520,
#  'reticent': 61,
#  'packed': 1362,
#  'abrasive': 124,
#  'Dark': 953,
#  'equal': 367,
#  'lightweight': 163,
#  'simple': 2627,
#  'meaty': 855,
#  'medium': 4516,
#  'rocky': 124,
#  'sensible': 3,
#  'made': 2917,
#  'assertive': 568,
#  'surprising': 173,
#  'Concentrated': 344,
#  'Pretty': 318,
#  'alluring': 258,
#  'steely': 842,
#  'Soft': 1091,
#  'upfront': 346,
#  'pungent': 290,
#  'labeled': 155,
#  'fragrant': 1204,
#  'floral': 2562,
#  'Heavy': 140,
#  'well': 9847,
#  'typical': 670,
#  'saline': 274,
#  'cloying': 243,
#  'modern': 526,
#  'sound': 120,
#  'nice': 1868,
#  'blended': 485,
#  'proper': 193,
#  'potential': 1173,
#  'colored': 722,
#  'native': 259,
#  'dominated': 675,
#  'graceful': 139,
#  'Far': 20,
#  'tannic': 4680,
#  'closed': 416,
#  'main': 191,
#  'tough': 624,
#  'south': 188,
#  'Sicilian': 80,
#  'international': 55,
#  'beautiful': 1077,
#  'golden': 540,
#  'lasting': 681,
#  'strong': 2026,
#  'tense': 268,
#  'Peppery': 106,
#  'thin': 633,
#  'vegetal': 388,
#  'obvious': 202,
#  'going': 758,
#  'hard': 1749,
#  'ungenerous': 14,
#  'consistent': 189,
#  'friendly': 898,
#  'many': 1113,
#  'single': 927,
#  'given': 651,
#  'planted': 514,
#  'flavorful': 511,
#  'Best': 611,
#  'available': 158,
#  'Continuing': 5,
#  'historic': 175,
#  'rare': 360,
#  'explosive': 111,
#  'gentle': 776,
#  'Small': 41,
#  'plus': 533,
#  'used': 294,
#  'otherwise': 444,
#  'mannered': 29,
#  'Structured': 174,
#  'last': 436,
#  'Black': 795,
#  'loamy': 178,
#  'eastern': 105,
#  'sticky': 339,
#  'easy': 3528,
#  'massive': 250,
#  'flashy': 235,
#  'structured': 3809,
#  'Minty': 75,
#  'bay': 315,
#  'Firm': 506,
#  'subtle': 1683,
#  'Aging': 45,
#  'softened': 199,
#  'intact': 29,
#  'flinty': 244,
#  'Generous': 118,
#  'brawny': 292,
#  'Earthy': 576,
#  'lovely': 1407,
#  'Fruity': 282,
#  'aromatic': 1872,
#  'modest': 680,
#  'level': 700,
#  'lean': 1662,
#  'fair': 201,
#  'residual': 635,
#  'Cool': 70,
#  'grassy': 497,
#  'wiry': 158,
#  'Herbal': 273,
#  'distinct': 255,
#  'rough': 540,
#  'Ripe': 1554,
#  'blue': 1293,
#  'together': 1756,
#  'chopped': 616,
#  'Rubbery': 106,
#  'generic': 437,
#  'hot': 885,
#  'natural': 578,
#  'textured': 2143,
#  'New': 401,
#  'three': 654,
#  'mellow': 590,
#  'exaggerated': 24,
#  'sage': 1334,
#  'impressive': 1334,
#  'top': 997,
#  'debatable': 1,
#  'salty': 691,
#  'fluid': 70,
#  'heavy': 1629,
#  'held': 196,
#  'bone': 611,
#  'chunky': 952,
#  'leafy': 532,
#  'sparkling': 631,
#  'central': 154,
#  'watery': 166,
#  'split': 37,
#  'rugged': 263,
#  'former': 60,
#  'latter': 35,
#  'healthy': 316,
#  'pithy': 496,
#  'executed': 46,
#  'designate': 238,
#  'Lively': 197,
#  'raising': 6,
#  'headfirst': 2,
#  'Grand': 203,
#  'express': 50,
#  'individual': 39,
#  'Labeled': 14,
#  'Solid': 192,
#  'layered': 1582,
#  'Astringent': 49,
#  'delicate': 1781,
#  'Baked': 225,
#  'caramel': 1855,
#  'inviting': 681,
#  'developed': 141,
#  'fat': 400,
#  'Yellow': 148,
#  'Alpine': 86,
#  'direct': 396,
#  'strung': 23,
#  'Chewy': 70,
#  'vibrant': 1719,
#  'special': 219,
#  'double': 12,
#  'distinctive': 354,
#  'Tannic': 85,
#  'Chunky': 94,
#  'soupy': 89,
#  'chubby': 11,
#  'Subtle': 242,
#  'expansive': 147,
#  'even': 1619,
#  'grand': 114,
#  'tame': 99,
#  'stainless': 542,
#  'gingery': 28,
#  'featured': 17,
#  'basic': 637,
#  'wound': 598,
#  'rubber': 513,
#  'rubbery': 641,
#  'comfortable': 57,
#  'cleanly': 44,
#  'bracing': 651,
#  'yeasty': 632,
#  'edgy': 366,
#  'approachable': 882,
#  'Heady': 82,
#  'built': 371,
#  'peppery': 1744,
#  'potent': 243,
#  'future': 433,
#  'open': 1345,
#  'super': 342,
#  'chicken': 338,
#  'first': 1779,
#  'encouraging': 22,
#  'sharp': 1358,
#  'bad': 130,
#  'flush': 150,
#  'perfected': 2,
#  'liquid': 75,
#  'chewy': 1464,
#  'decadent': 220,
#  'Even': 164,
#  'excellent': 832,
#  'capped': 53,
#  'far': 404,
#  'east': 95,
#  'drinkable': 587,
#  'polish': 224,
#  'Tight': 267,
#  'limited': 243,
#  'acidic': 1099,
#  'toned': 692,
#  'two': 1317,
#  'rounded': 2030,
#  'enjoyable': 549,
#  'marked': 557,
#  'revealing': 154,
#  'joined': 137,
#  'secret': 13,
#  'Honey': 122,
#  'filled': 389,
#  'Fresh': 1180,
#  'nutty': 455,
#  'chemical': 65,
#  'angular': 178,
#  'Cultivated': 1,
#  'ago': 84,
#  'One': 497,
#  'cheerful': 154,
#  'northern': 277,
#  'low': 856,
#  'old': 1491,
#  'backed': 1085,
#  'hollow': 131,
#  'heady': 408,
#  'exquisite': 102,
#  'Austrian': 40,
#  'precise': 203,
#  'broad': 792,
#  'Red': 747,
#  'Big': 466,
#  'drenched': 68,
#  'pale': 451,
#  'Green': 277,
#  'Rose': 91,
#  'flying': 8,
#  'another': 844,
#  'oxidized': 192,
#  'go': 1017,
#  'done': 245,
#  'sustained': 61,
#  'whole': 579,
#  'Great': 257,
#  'North': 51,
#  'superb': 195,
#  'following': 73,
#  'organic': 254,
#  'growing': 134,
#  'contingent': 1,
#  'Dry': 1041,
#  'ideal': 250,
#  'staple': 5,
#  'smaller': 177,
#  'Light': 1245,
#  'Textured': 50,
#  'neither': 64,
#  'final': 632,
#  'opposed': 14,
#  'worthy': 193,
#  'shaded': 42,
#  'Elegant': 201,
#  'Good': 570,
#  'dotted': 68,
#  'taut': 752,
#  'White': 237,
#  'away': 540,
#  'Italian': 356,
#  'according': 22,
#  'dynamic': 103,
#  'shaped': 77,
#  'everyday': 534,
#  'located': 102,
#  'lavish': 156,
#  'exceptional': 189,
#  'Smooth': 472,
#  'Spanish': 254,
#  'past': 330,
#  'stopped': 8,
#  'accompanied': 256,
#  'starting': 254,
#  'assaultive': 4,
#  'serious': 716,
#  'impatient': 2,
#  'sleek': 302,
#  'considerable': 392,
#  'Pure': 191,
#  'liked': 5,
#  'leading': 491,
#  'Asian': 596,
#  'meaning': 112,
#  'likely': 506,
#  'near': 449,
#  'seamless': 190,
#  'Rusty': 26,
#  'murky': 108,
#  'clipped': 71,
#  'jagged': 87,
#  'rear': 31,
#  'coveted': 28,
#  'Golden': 252,
#  'focused': 993,
#  'indistinguishable': 7,
#  'Rich': 923,
#  'cushioned': 109,
#  'must': 79,
#  'heated': 3,
#  'veiled': 2,
#  'comforting': 28,
#  'glowing': 12,
#  'woodsy': 96,
#  'sure': 222,
#  'salt': 423,
#  'Loaded': 37,
#  'small': 885,
#  'Together': 79,
#  'representative': 26,
#  'restrained': 769,
#  'Exuberant': 21,
#  'concealed': 5,
#  'home': 253,
#  'endowed': 68,
#  'wide': 342,
#  'stellar': 86,
#  'blown': 28,
#  'Creamy': 222,
#  'Complex': 166,
#  'eight': 175,
#  'Portuguese': 78,
#  'Poised': 17,
#  'oily': 471,
#  'Deep': 285,
#  'Half': 61,
#  'popular': 235,
#  'pressed': 689,
#  'derived': 96,
#  'center': 519,
#  'surrounded': 175,
#  'difficult': 225,
#  'alpine': 62,
#  'reliant': 5,
#  'matched': 162,
#  'beery': 12,
#  'tasty': 697,
#  'entire': 79,
#  'Primary': 13,
#  'sizzling': 63,
#  'complete': 380,
#  'dimensional': 353,
#  'volatile': 105,
#  'footed': 156,
#  'energetic': 120,
#  'facile': 6,
#  'Taut': 47,
#  'slender': 440,
#  'found': 262,
#  'classified': 18,
#  'varied': 25,
#  'extraordinary': 64,
#  'Glorious': 5,
#  'vivid': 406,
#  'dazzling': 84,
#  'High': 281,
#  'Clean': 270,
#  'standard': 353,
#  'Mild': 129,
#  'grapey': 97,
#  'directed': 9,
#  'important': 159,
#  'beguiling': 75,
#  'beginning': 251,
#  'unexpected': 47,
#  'stunning': 176,
#  'hefty': 151,
#  'Interesting': 41,
#  'soothing': 83,
#  'turned': 279,
#  'rust': 46,
#  'damp': 140,
#  'Lovely': 208,
#  'northwestern': 7,
#  'Juicy': 489,
#  'nervy': 265,
#  'early': 358,
#  'extra': 853,
#  'plastic': 116,
#  'thick': 1630,
#  'canned': 131,
#  'Complete': 4,
#  'informal': 264,
#  'enclosed': 2,
#  'scorched': 297,
#  'expressive': 434,
#  'Leafy': 79,
#  'amazing': 112,
#  'less': 607,
#  'careful': 43,
#  'latest': 93,
#  'exciting': 163,
#  'sprightly': 177,
#  'brown': 761,
#  'ahead': 181,
#  'quiet': 105,
#  'Typical': 44,
#  'huge': 342,
#  'discernible': 15,
#  'adjacent': 14,
#  'Rough': 35,
#  'boned': 111,
#  'substantial': 372,
#  'demanding': 54,
#  'easygoing': 649,
#  'sliced': 179,
#  'saved': 25,
#  'beefy': 99,
#  'unorthodox': 4,
#  'appetizing': 400,
#  'known': 532,
#  'second': 398,
#  'certified': 75,
#  'roast': 248,
#  'Central': 152,
#  'intriguing': 649,
#  'continuing': 29,
#  'reflecting': 39,
#  'possible': 115,
#  'emerging': 84,
#  'northernmost': 14,
#  'American': 347,
#  'alcoholic': 126,
#  'welcoming': 103,
#  'noted': 20,
#  'poised': 278,
#  'herbaceous': 480,
#  'sufficient': 41,
#  'regular': 266,
#  'dramatic': 151,
#  'Dried': 238,
#  'real': 459,
#  'characteristic': 233,
#  'Floral': 294,
#  'sublime': 52,
#  'bushy': 3,
#  'oriented': 17,
#  'pleasing': 618,
#  'Damask': 10,
#  'tempering': 5,
#  'fortunate': 10,
#  'active': 12,
#  'cured': 457,
#  'Port': 347,
#  'Inviting': 45,
#  'stripped': 18,
#  'fiery': 114,
#  'subordinate': 2,
#  'mid': 246,
#  'worth': 356,
#  'Balanced': 233,
#  'brooding': 556,
#  'showy': 97,
#  'Corsican': 8,
#  'sturdy': 269,
#  'Vanilla': 195,
#  'multiple': 78,
#  'Fine': 204,
#  'fleeting': 220,
#  'spiked': 52,
#  'faint': 271,
#  'supported': 477,
#  'melted': 195,
#  'airy': 89,
#  'Medium': 597,
#  'straight': 209,
#  'incidental': 1,
#  'lost': 114,
#  'lighted': 3,
#  'Young': 177,
#  'seductive': 301,
#  'Long': 185,
#  'laden': 229,
#  'Short': 59,
#  'harsh': 169,
#  'African': 33,
#  'loaded': 610,
#  'sandpapery': 32,
#  'granitic': 10,
#  'initial': 185,
#  'farther': 4,
#  'north': 191,
#  'cold': 193,
#  'persistent': 502,
#  'variable': 12,
#  'composed': 239,
#  'piquant': 99,
#  'Like': 297,
#  'detailed': 143,
#  'abundant': 234,
#  'shy': 383,
#  'funky': 392,
#  'oppressive': 2,
#  'interesting': 909,
#  'allied': 79,
#  'edged': 254,
#  'lactic': 137,
#  'sophisticated': 452,
#  'designed': 67,
#  'Separate': 1,
#  'Original': 6,
#  'South': 88,
#  'Lush': 172,
#  'expressed': 57,
#  'expensive': 176,
#  'eccentric': 34,
#  'Subdued': 111,
#  'bulky': 82,
#  'normal': 64,
#  'Round': 243,
#  'definite': 106,
#  'metallic': 91,
#  'thrown': 49,
#  'attenuated': 21,
#  'appealing': 893,
#  'tempered': 125,
#  'decent': 348,
#  'detectable': 28,
#  'finished': 238,
#  'satisfied': 3,
#  'compelling': 425,
#  'unmistakable': 24,
#  'choppy': 300,
#  'Salty': 77,
#  'driving': 149,
#  'barbecued': 79,
#  'Integrated': 42,
#  'exemplary': 41,
#  'improving': 25,
#  'Aged': 364,
#  'elevated': 85,
#  'lessened': 2,
#  'Chalky': 34,
#  'abrupt': 91,
#  'Mediterranean': 463,
#  'Pithy': 59,
#  'Decent': 36,
#  'Austere': 30,
#  'muscular': 284,
#  'diluted': 104,
#  'quick': 210,
#  'delightful': 233,
#  'peachy': 195,
#  'uncomplicated': 119,
#  'Six': 22,
#  'six': 571,
#  'Intriguing': 55,
#  'Quick': 15,
#  'particular': 129,
#  'cranky': 2,
#  'trying': 68,
#  'Electric': 10,
#  'loud': 94,
#  'Plummy': 32,
#  'Sultry': 17,
#  'pitched': 24,
#  'true': 408,
#  'laced': 705,
#  'Cut': 16,
#  'sensational': 26,
#  'reasonable': 69,
#  'running': 169,
#  'spread': 58,
#  'excess': 42,
#  'immediate': 257,
#  'feral': 101,
#  'Buttery': 22,
#  'yielding': 193,
#  'steady': 197,
#  'Seven': 81,
#  'sappy': 141,
#  'Superb': 9,
#  'ethereal': 177,
#  'waiting': 111,
#  'scented': 347,
#  'diffuse': 33,
#  'cross': 32,
#  'aimless': 2,
#  'elusive': 82,
#  'Premier': 87,
#  'Huge': 33,
#  'alive': 120,
#  'True': 45,
#  'accessible': 607,
#  'solo': 25,
#  'awkward': 131,
#  'acceptable': 47,
#  'Intense': 257,
#  'Bold': 215,
#  'stiff': 179,
#  'usual': 191,
#  'extended': 148,
#  'enhanced': 262,
#  'dominant': 417,
#  'Alto': 26,
#  'extreme': 210,
#  'public': 3,
#  'odd': 122,
#  'convincing': 69,
#  'Dominated': 96,
#  'Fiery': 16,
#  'underdeveloped': 13,
#  'evocative': 54,
#  'Bitter': 50,
#  'apparent': 217,
#  'common': 156,
#  'Vibrant': 196,
#  'tidal': 5,
#  'Nervy': 24,
#  'present': 412,
#  'defined': 395,
#  'German': 41,
#  'developing': 475,
#  'delineated': 28,
#  'admirable': 42,
#  'Imported': 172,
#  'Pacific': 38,
#  'warming': 74,
#  'owned': 244,
#  'previous': 146,
#  'topped': 143,
#  'intensive': 5,
#  'skinned': 664,
#  'saturated': 339,
#  'descending': 2,
#  'opened': 73,
#  'smothered': 25,
#  'ranging': 82,
#  'elaborate': 88,
#  'traditional': 354,
#  'Yeasty': 101,
#  'able': 68,
#  'carnation': 33,
#  'brittle': 52,
#  'third': 214,
#  'breathing': 125,
#  'Caramel': 41,
#  'seven': 135,
#  'paired': 137,
#  'imported': 49,
#  'searing': 71,
#  'ginger': 603,
#  'falling': 34,
#  'Turkish': 32,
#  'inflected': 80,
#  'excessive': 77,
#  'classy': 201,
#  'Candied': 123,
#  'unrecognizable': 3,
#  'successful': 145,
#  'Sweet': 501,
#  'greater': 128,
#  'overt': 115,
#  'surface': 172,
#  'underlying': 372,
#  'fantastic': 112,
#  'significant': 68,
#  'Cloudy': 25,
#  'flamboyant': 114,
#  'fast': 141,
#  'approaching': 46,
#  'tender': 45,
#  'braised': 50,
#  'Right': 150,
#  'noticeable': 197,
#  'playful': 126,
#  'fabulous': 82,
#  'reflective': 37,
#  'tawny': 112,
#  'fortified': 55,
#  'Certain': 4,
#  'Well': 215,
#  'seared': 114,
#  'tilled': 403,
#  'brilliant': 177,
#  'gingerly': 6,
#  'Blended': 200,
#  'reduced': 188,
#  'competent': 24,
#  'Cold': 32,
#  'unconventional': 7,
#  'thrilling': 40,
#  'Mint': 74,
#  'feisty': 6,
#  'hidden': 63,
#  'Pale': 118,
#  'absorbed': 13,
#  'syrupy': 436,
#  'Packaged': 52,
#  'cloudy': 42,
#  'salted': 119,
#  'choice': 220,
#  'Robust': 67,
#  'Flush': 12,
#  'fried': 108,
#  'Chinese': 96,
#  'Easy': 224,
#  'galore': 25,
#  'masculine': 125,
#  'orchestrated': 3,
#  'Balsamic': 15,
#  'controlled': 129,
#  'related': 84,
#  'fledged': 13,
#  'smoothed': 108,
#  'Similar': 38,
#  'Catalan': 5,
#  'opaque': 57,
#  'Wild': 107,
#  'Strong': 141,
#  'vital': 128,
#  'familiar': 151,
#  'certain': 187,
#  'earthen': 15,
#  'sanguine': 107,
#  'every': 294,
#  'Gorgeous': 54,
#  'Linear': 31,
#  'Loamy': 25,
#  'Indian': 173,
#  'Side': 3,
#  'Christian': 17,
#  'Peachy': 24,
#  'Georgian': 19,
#  'due': 335,
#  'buried': 70,
#  'Early': 20,
#  'nine': 78,
#  'likable': 93,
#  'snappy': 413,
#  'crackle': 3,
#  'smoked': 873,
#  'listed': 57,
#  'expected': 136,
#  'sized': 53,
#  'Invigorating': 11,
#  'gone': 40,
#  'disjointed': 125,
#  'Funky': 48,
#  ...}

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-d7641c260a64> in <module>
#       1 for key in descriptors_dict:
# ----> 2     X_train[key] = X_train['description_split'].count(key)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in count(self, level)
#    1890
#    1891         if isinstance(level, str):
# -> 1892             level = self.index._get_level_number(level)
#    1893
#    1894         lev = self.index.levels[level]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _get_level_number(self, level)
#    1561
#    1562     def _get_level_number(self, level):
# -> 1563         self._validate_index_level(level)
#    1564         return 0
#    1565
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _validate_index_level(self, level)
#    1556             raise KeyError(
#    1557                 "Requested level ({}) does not match index name ({})".format(
# -> 1558                     level, self.name
#    1559                 )
#    1560             )
#
# KeyError: 'Requested level (remarkable) does not match index name (None)'

# %%
X_train = X_train[['country', 'points', 'province', 'description_split']]

X_train
# Out:
#           country  points            province  \
# 56921       Italy      87  Northeastern Italy
# 7894       France      84    Southwest France
# 24745       Chile      85    Cachapoal Valley
# 9828    Australia      89     South Australia
# 124193    Austria      94              Wachau
# ...           ...     ...                 ...
# 128343      Spain      88           Catalonia
# 103876         US      88            New York
# 860            US      90          California
# 15820          US      85          California
# 122183         US      88          Washington
#
#                                         description_split
# 56921   [Moscato, Giallo, remarkable, ability, appeari...
# 7894    [is, typically, light, fruity, wine, Gascony, ...
# 24745   [Sharp, aromas, prickly, red, fruits, barrel, ...
# 9828    [Cassis, chocolate, notes, dominate, there, en...
# 124193  [nose, opens, totally, tangy, note, lemon, zes...
# ...                                                   ...
# 128343  [Schisty, red, fruit, aromas, come, hints, van...
# 103876  [initially, closed, suggesting, bit, more, bra...
# 860     [Fresh, cracked, peppercorn, dense, black, pur...
# 15820   [little, one, dimensional, in, apricot, citrus...
# 122183  [blend, 52, Syrah, 34, Cabernet, Sauvignon, 14...
#
# [97299 rows x 4 columns]

# %%
# Scale your data

X_scaler = StandardScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
