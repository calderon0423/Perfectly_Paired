# %%
import pandas as pd

# %%
red = pd.read_csv("../Red_and_White_Analysis/Data/winequality-red-reformatted.csv")
red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
fixed = red["fixed acidity"].unique().tolist()
fixed
# Out:
# [7.4,
#  7.8,
#  11.2,
#  7.9,
#  7.3,
#  7.5,
#  6.7,
#  5.6,
#  8.9,
#  8.5,
#  8.1,
#  7.6,
#  6.9,
#  6.3,
#  7.1,
#  8.3,
#  5.2,
#  5.7,
#  8.8,
#  6.8,
#  4.6,
#  7.7,
#  8.7,
#  6.4,
#  6.6,
#  8.6,
#  10.2,
#  7.0,
#  7.2,
#  9.3,
#  8.0,
#  9.7,
#  6.2,
#  5.0,
#  4.7,
#  8.4,
#  10.1,
#  9.4,
#  9.0,
#  8.2,
#  6.1,
#  5.8,
#  9.2,
#  11.5,
#  5.4,
#  9.6,
#  12.8,
#  11.0,
#  11.6,
#  12.0,
#  15.0,
#  10.8,
#  11.1,
#  10.0,
#  12.5,
#  11.8,
#  10.9,
#  10.3,
#  11.4,
#  9.9,
#  10.4,
#  13.3,
#  10.6,
#  9.8,
#  13.4,
#  10.7,
#  11.9,
#  12.4,
#  12.2,
#  13.8,
#  9.1,
#  13.5,
#  10.5,
#  12.6,
#  14.0,
#  13.7,
#  9.5,
#  12.7,
#  12.3,
#  15.6,
#  5.3,
#  11.3,
#  13.0,
#  6.5,
#  12.9,
#  14.3,
#  15.5,
#  11.7,
#  13.2,
#  15.9,
#  12.1,
#  5.1,
#  4.9,
#  5.9,
#  6.0,
#  5.5]

# %%
volatile = red["volatile acidity"].unique().tolist()
volatile
# Out:
# [0.7,
#  0.88,
#  0.76,
#  0.28,
#  0.66,
#  0.6,
#  0.65,
#  0.58,
#  0.5,
#  0.615,
#  0.61,
#  0.62,
#  0.56,
#  0.59,
#  0.32,
#  0.22,
#  0.39,
#  0.43,
#  0.49,
#  0.4,
#  0.41,
#  0.71,
#  0.645,
#  0.675,
#  0.685,
#  0.655,
#  0.605,
#  0.38,
#  1.13,
#  0.45,
#  0.67,
#  0.52,
#  0.935,
#  0.29,
#  0.31,
#  0.51,
#  0.42,
#  0.63,
#  0.69,
#  0.735,
#  0.725,
#  0.705,
#  0.785,
#  0.75,
#  0.625,
#  0.3,
#  0.55,
#  1.02,
#  0.775,
#  0.9,
#  0.545,
#  0.575,
#  0.33,
#  0.54,
#  1.07,
#  0.695,
#  1.33,
#  0.745,
#  1.04,
#  0.715,
#  0.415,
#  0.34,
#  0.68,
#  0.95,
#  0.53,
#  0.64,
#  0.885,
#  0.805,
#  0.73,
#  0.37,
#  0.835,
#  1.09,
#  0.57,
#  0.44,
#  0.635,
#  0.82,
#  0.48,
#  1.0,
#  0.21,
#  0.35,
#  0.975,
#  0.26,
#  0.87,
#  0.18,
#  0.27,
#  0.2,
#  0.36,
#  0.83,
#  0.46,
#  0.47,
#  0.77,
#  0.815,
#  0.795,
#  0.665,
#  0.765,
#  0.24,
#  0.85,
#  0.84,
#  0.96,
#  0.78,
#  0.23,
#  0.315,
#  0.365,
#  0.25,
#  0.825,
#  0.72,
#  0.595,
#  0.585,
# ...

# %%
citric = red["citric acid"].unique().tolist()
citric
# Out:
# [0.0,
#  0.04,
#  0.56,
#  0.06,
#  0.02,
#  0.36,
#  0.08,
#  0.29,
#  0.18,
#  0.19,
#  0.28,
#  0.51,
#  0.48,
#  0.31,
#  0.21,
#  0.11,
#  0.14,
#  0.16,
#  0.24,
#  0.07,
#  0.12,
#  0.25,
#  0.09,
#  0.3,
#  0.2,
#  0.22,
#  0.15,
#  0.43,
#  0.52,
#  0.23,
#  0.37,
#  0.26,
#  0.57,
#  0.4,
#  0.49,
#  0.05,
#  0.54,
#  0.64,
#  0.7,
#  0.47,
#  0.44,
#  0.17,
#  0.68,
#  0.53,
#  0.1,
#  0.01,
#  0.55,
#  1.0,
#  0.03,
#  0.42,
#  0.33,
#  0.32,
#  0.35,
#  0.6,
#  0.74,
#  0.58,
#  0.5,
#  0.76,
#  0.46,
#  0.45,
#  0.38,
#  0.39,
#  0.66,
#  0.62,
#  0.67,
#  0.79,
#  0.63,
#  0.61,
#  0.71,
#  0.65,
#  0.59,
#  0.34,
#  0.69,
#  0.73,
#  0.72,
#  0.41,
#  0.27,
#  0.75,
#  0.13,
#  0.78]

# %%
sugar = red["residual sugar"].unique().tolist()
sugar
# Out:
# [1.9,
#  2.6,
#  2.3,
#  1.8,
#  1.6,
#  1.2,
#  2.0,
#  6.1,
#  3.8,
#  3.9,
#  1.7,
#  4.4,
#  2.4,
#  1.4,
#  2.5,
#  10.7,
#  5.5,
#  2.1,
#  1.5,
#  5.9,
#  2.8,
#  2.2,
#  3.0,
#  3.4,
#  5.1,
#  4.65,
#  1.3,
#  7.3,
#  7.2,
#  2.9,
#  2.7,
#  5.6,
#  3.1,
#  3.2,
#  3.3,
#  3.6,
#  4.0,
#  7.0,
#  6.4,
#  3.5,
#  11.0,
#  3.65,
#  4.5,
#  4.8,
#  2.95,
#  5.8,
#  6.2,
#  4.2,
#  7.9,
#  3.7,
#  6.7,
#  6.6,
#  2.15,
#  5.2,
#  2.55,
#  15.5,
#  4.1,
#  8.3,
#  6.55,
#  4.6,
#  4.3,
#  5.15,
#  6.3,
#  6.0,
#  8.6,
#  7.5,
#  2.25,
#  4.25,
#  2.85,
#  3.45,
#  2.35,
#  2.65,
#  9.0,
#  8.8,
#  5.0,
#  1.65,
#  2.05,
#  0.9,
#  8.9,
#  8.1,
#  4.7,
#  1.75,
#  7.8,
#  12.9,
#  13.4,
#  5.4,
#  15.4,
#  3.75,
#  13.8,
#  5.7,
#  13.9]

# %%
ph =red["pH"].unique().tolist()
ph
# Out:
# [3.51,
#  3.2,
#  3.26,
#  3.16,
#  3.3,
#  3.39,
#  3.36,
#  3.35,
#  3.28,
#  3.58,
#  3.17,
#  3.11,
#  3.38,
#  3.04,
#  3.52,
#  3.43,
#  3.34,
#  3.47,
#  3.46,
#  3.45,
#  3.4,
#  3.42,
#  3.23,
#  3.5,
#  3.33,
#  3.21,
#  3.48,
#  3.9,
#  3.25,
#  3.32,
#  3.15,
#  3.41,
#  3.44,
#  3.31,
#  3.54,
#  3.13,
#  2.93,
#  3.14,
#  3.75,
#  3.85,
#  3.29,
#  3.08,
#  3.37,
#  3.19,
#  3.07,
#  3.49,
#  3.53,
#  3.24,
#  3.63,
#  3.22,
#  3.68,
#  2.74,
#  3.59,
#  3.0,
#  3.12,
#  3.57,
#  3.61,
#  3.06,
#  3.6,
#  3.69,
#  3.1,
#  3.05,
#  3.67,
#  3.27,
#  3.18,
#  3.02,
#  3.55,
#  2.99,
#  3.01,
#  3.56,
#  3.03,
#  3.62,
#  2.88,
#  2.95,
#  2.98,
#  3.09,
#  2.86,
#  3.74,
#  2.92,
#  3.72,
#  2.87,
#  2.89,
#  2.94,
#  3.66,
#  3.71,
#  3.78,
#  3.7,
#  4.01,
#  2.9]

# %%
alc = red["alcohol"].unique().tolist()
alc
# Out:
# [9.4,
#  9.8,
#  10.0,
#  9.5,
#  10.5,
#  9.2,
#  9.9,
#  9.1,
#  9.3,
#  9.0,
#  9.7,
#  10.1,
#  10.6,
#  9.6,
#  10.8,
#  10.3,
#  13.1,
#  10.2,
#  10.9,
#  10.7,
#  12.9,
#  10.4,
#  13.0,
#  14.0,
#  11.5,
#  11.4,
#  12.4,
#  11.0,
#  12.2,
#  12.8,
#  12.6,
#  12.5,
#  11.7,
#  11.3,
#  12.3,
#  12.0,
#  11.9,
#  11.8,
#  8.7,
#  13.3,
#  11.2,
#  11.6,
#  11.1,
#  13.4,
#  12.1,
#  8.4,
#  12.7,
#  14.9,
#  13.2,
#  13.6,
#  13.5,
#  10.0333333333333,
#  9.55,
#  8.5,
#  11.066666666666698,
#  9.56666666666667,
#  10.55,
#  8.8,
#  13.566666666666698,
#  11.95,
#  9.95,
#  9.23333333333333,
#  9.25,
#  9.05,
#  10.75]
