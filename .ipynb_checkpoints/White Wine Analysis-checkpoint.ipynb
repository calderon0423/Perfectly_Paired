# %% [markdown]
# ## Exploring the White Wine Dataset
#
# - Which phsyiochemical property contributes most to high quality wine? Least?
# - What is the ideal numeric value of that property that will generate the highest quality wine?

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

from pandas.plotting import scatter_matrix
from sklearn.preprocessing import QuantileTransformer
from pandas import DataFrame as df

# %%
#Read in csv file
white = pd.read_csv("winequality_white.csv", sep=';', encoding='UTF8') 
# Drop the null columns where all values are null
white = white.dropna(axis='columns', how='all')
# Drop the null rows
white.dropna()
white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
metadata = white.describe()
metadata.round()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count         4898.0            4898.0       4898.0          4898.0
# mean             7.0               0.0          0.0             6.0
# std              1.0               0.0          0.0             5.0
# min              4.0               0.0          0.0             1.0
# 25%              6.0               0.0          0.0             2.0
# 50%              7.0               0.0          0.0             5.0
# 75%              7.0               0.0          0.0            10.0
# max             14.0               1.0          2.0            66.0
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density      pH  \
# count     4898.0               4898.0                4898.0   4898.0  4898.0
# mean         0.0                 35.0                 138.0      1.0     3.0
# std          0.0                 17.0                  42.0      0.0     0.0
# min          0.0                  2.0                   9.0      1.0     3.0
# 25%          0.0                 23.0                 108.0      1.0     3.0
# 50%          0.0                 34.0                 134.0      1.0     3.0
# 75%          0.0                 46.0                 167.0      1.0     3.0
# max          0.0                289.0                 440.0      1.0     4.0
#
#        sulphates  alcohol  quality
# count     4898.0   4898.0   4898.0
# mean         0.0     11.0      6.0
# std          0.0      1.0      1.0
# min          0.0      8.0      3.0
# 25%          0.0     10.0      5.0
# 50%          0.0     10.0      6.0
# 75%          1.0     11.0      6.0
# max          1.0     14.0      9.0

# %%
#Examining the distribution of each property
#PH level seems to be the most normally distributed
#Chlorides, Free of Sulfur dioxide and residual sugar appear to be the least normally distributed
white.hist(figsize=(12,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd0f9cbba50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0fa023d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0fa05e590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd0fa08ed90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0fa0ca5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0fa0fcdd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd0fa138cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0fa16ae10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0fa17f090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd0fa1af9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0fa216690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd0fa24ce90>]],
#       dtype=object)

# %%
#Explore white wine quality scores (scale of 1-10)
quality_score_summary = white["quality"].value_counts()
quality_summary.sort_index(ascending=True)
# Out:
# 3      20
# 4     163
# 5    1457
# 6    2198
# 7     880
# 8     175
# 9       5
# Name: quality, dtype: int64

# %%
std = white["free sulfur dioxide"].std()
mean = white["free sulfur dioxide"].mean()

no_outlier_white = white[(white["free sulfur dioxide"] > (mean - 3*std)) & (white["free sulfur dioxide"] < (mean + 3*std))]
no_outlier_white.describe()

def remove_outlier(col_name,df):
    std = df[col_name].std()
    mean = df[col_name].mean()

    no_outlier_white = df[(df[col_name] > (mean - 3*std)) & (df[col_name] < (mean + 3*std))]
    return no_outlier_white

# %%
df = white
for i in list(white.columns):
    print (i)
    df = remove_outlier(i,df)
    


df.round()

df.describe()
# Out:
# fixed acidity
# volatile acidity
# citric acid
# residual sugar
# chlorides
# free sulfur dioxide
# total sulfur dioxide
# density
# pH
# sulphates
# alcohol
# quality
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4469.000000       4469.000000  4469.000000     4469.000000
# mean        6.840982          0.270621     0.326695        6.415563
# std         0.785104          0.085136     0.100878        4.955954
# min         4.400000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.310000        5.300000
# 75%         7.300000          0.320000     0.380000        9.900000
# max         9.300000          0.570000     0.690000       20.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4469.000000          4469.000000           4469.000000  4469.000000
# mean      0.043105            34.845715            137.591407     0.993968
# std       0.011508            15.399909             41.297292     0.002907
# min       0.012000             2.000000             21.000000     0.987110
# 25%       0.035000            23.000000            108.000000     0.991680
# 50%       0.043000            34.000000            133.000000     0.993700
# 75%       0.050000            45.000000            166.000000     0.996100
# max       0.105000            85.000000            260.000000     1.001960
#
#                 pH    sulphates      alcohol      quality
# count  4469.000000  4469.000000  4469.000000  4469.000000
# mean      3.187995     0.485413    10.537077     5.915194
# std       0.143240     0.105729     1.223274     0.854036
# min       2.790000     0.220000     8.400000     4.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.540000    11.400000     6.000000
# max       3.630000     0.820000    14.200000     8.000000

# %% [markdown]
# ## Multicollinearity Check
#
# The dataset's variable's will be checked for multicollinearity by examining the (Variance Inflation Factor VIF). This will also verify if we have a sound model (testing an assumption (multicollinearity) for a multiple regression analysis.
#
# - How related (if at all) are the properties to one another?

# %%
# CHECK FOR MULTICOLLINEARITY with Variance Inflation Factor
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Physiochemical Variables"] = X.columns

# %%
#Reset Index or drop when cleaning up notebook
vif = vif.sort_values(by=["VIF Factor"]).round(1)
vif
# Out:
#     VIF Factor Physiochemical Variables
# 3          3.8           residual sugar
# 4          6.5                chlorides
# 5          9.3      free sulfur dioxide
# 1          9.7         volatile acidity
# 2         10.0              citric acid
# 9         20.5                sulphates
# 6         25.0     total sulfur dioxide
# 0         92.9            fixed acidity
# 10       118.7                  alcohol
# 8        609.9                       pH
# 7       1056.5                  density

# %%
phys_c = white.drop("quality", axis = 1)

phys_corr = phys_c.corr()
phys_corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.089021   0.023086            -0.049396
# volatile acidity            0.064286   0.070512            -0.097012
# citric acid                 0.094212   0.114364             0.094077
# residual sugar              1.000000   0.088685             0.299098
# chlorides                   0.088685   1.000000             0.101392
# free sulfur dioxide         0.299098   0.101392             1.000000
# total sulfur dioxide        0.401439   0.198910             0.615501
# density                     0.838966   0.257211             0.294210
# pH                         -0.194133  -0.090439            -0.000618
# sulphates                  -0.026664   0.016763             0.059217
# alcohol                    -0.450631  -0.360189            -0.250104
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                     0.091070  0.265331 -0.425858  -0.017143
# volatile acidity                  0.089261  0.027114 -0.031915  -0.035728
# citric acid                       0.121131  0.149503 -0.163748   0.062331
# residual sugar                    0.401439  0.838966 -0.194133  -0.026664
# chlorides                         0.198910  0.257211 -0.090439   0.016763
# free sulfur dioxide               0.615501  0.294210 -0.000618   0.059217
# total sulfur dioxide              1.000000  0.529881  0.002321   0.134562
# density                           0.529881  1.000000 -0.093591   0.074493
# pH                                0.002321 -0.093591  1.000000   0.155951
# sulphates                         0.134562  0.074493  0.155951   1.000000
# alcohol                          -0.448892 -0.780138  0.121432  -0.017433
#
#                        alcohol
# fixed acidity        -0.120881
# volatile acidity      0.067718
# citric acid          -0.075729
# residual sugar       -0.450631
# chlorides            -0.360189
# free sulfur dioxide  -0.250104
# total sulfur dioxide -0.448892
# density              -0.780138
# pH                    0.121432
# sulphates            -0.017433
# alcohol               1.000000

# %%
#Displays the the correlation ( r, not r^2 like VIF) between each independent variable to oneanother (physochemical var's, excludes quality) 
#to provide additional evidence of collinearity

import seaborn as sns 
corr = vif_df.corr()
fig = plt.subplots(figsize=(12,10))
sns.heatmap(phys_corr,square=True,annot=True,cmap='YlGnBu')
plt.title("Correlation among the predictors")
# Out:
# Text(0.5, 1, 'Correlation among the predictors')

# %% [markdown]
# ## Residuals
# -Residual sugar is least correlated with the  remaining variables. Most of the variables are are highly correlated with one another, especially density.
# -Residuals appear to be normal (symetrical), but there is an outlier that can be skiewing the model.

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")

plt.legend()

plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.xlabel("Predicted Values")
plt.ylabel("Residual Values")
plt.title("Residual Plot")
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %% [markdown]
# ## Using Z-Score to mathatmetically identify outliers to remove.

# %%
#All Z-Scores
z = np.abs(stats.zscore(white))
print(z)
# Out:
# [[1.72096961e-01 8.17699008e-02 2.13280202e-01 ... 3.49184257e-01
#   1.39315246e+00 1.37870140e-01]
#  [6.57501128e-01 2.15895632e-01 4.80011213e-02 ... 1.34184656e-03
#   8.24275678e-01 1.37870140e-01]
#  [1.47575110e+00 1.74519434e-02 5.43838363e-01 ... 4.36815783e-01
#          4,  0,  0,  8,  5,  5,  4,  4,  8,  2, 11,  0,  6,  1,  8,  9,  0,
#          1,  1,  4,  9,  2,  2,  4,  4,  4,  4,  1,  9,  5,  1,  2,  9,  2,
#          9,  4,  8,  4,  1,  6,  0,  1,  9,  4,  4,  8,  1,  1,  5,  9,  5,
#          9,  8,  1,  3,  7,  2,  2,  2,  4,  4,  0,  5,  8,  9,  9,  9,  9,
#          9,  9,  9,  4,  8,  1,  8,  2,  4,  4,  5,  6,  4,  9,  2,  2,  5,
#         11,  0,  0,  1,  8,  2,  6,  1,  9,  4,  0, 11,  4,  4,  0,  5, 11,
#          5,  5, 11,  1,  9,  5,  5,  2,  5,  5,  1,  4,  8,  1,  1,  1,  2,
#          2,  2,  3,  5,  3,  4,  4,  4,  9,  9,  1,  1,  6,  4,  2,  4,  1,
#         11,  2,  4,  5,  5,  5,  5,  5,  5,  1,  1,  6,  4,  2,  4,  4,  4,
#          9,  9,  9,  9,  1,  8,  1,  2,  4,  4,  9,  4,  0,  8,  4,  4,  1,
#          4,  4,  9,  8,  4,  3,  4,  4,  1,  8,  8,  9,  2,  1,  1,  1,  2,
#          2,  1,  4,  1,  1,  1,  1,  9,  2,  4,  1,  1,  8,  5,  6, 11,  2,
#          1,  0,  1,  1,  9,  4,  4,  4,  1,  9,  9,  4,  5,  4,  1,  9]))

# %%
white_z = z_outliers_arrary[(z_outliers_arrary < 3).all(axis=1)]
white_z
# Out:
# array([], shape=(0, 475), dtype=int64)

# %% [markdown]
# # IQR to identify and remove outiers
# Notes to self: would like to see all true (or all outliers) before deciding which to remove. I believe there are outliers in the independent variables. Once outliers are removed, will need to re-run the 1) MRA 2) PCA and maybe 3) classification.

# %%
Q1 = white.quantile(0.25)
Q3 = white.quantile(0.75)
IQR = Q3 - Q1
lower_q = Q1 - 1.5 * IQR
upper_q = Q3 + 1.5 * IQR
print(IQR.round(2))
# Out:
# fixed acidity            1.00
# volatile acidity         0.11
# citric acid              0.12
# residual sugar           8.20
# chlorides                0.01
# free sulfur dioxide     23.00
# total sulfur dioxide    59.00
# density                  0.00
# pH                       0.19
# sulphates                0.14
# alcohol                  1.90
# quality                  1.00
# dtype: float64

# %%
df = white[(white < (Q1 - 1.5 * IQR)) |(white > (Q3 + 1.5 * IQR))]
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            NaN               NaN          NaN             NaN        NaN
# 1            NaN               NaN          NaN             NaN        NaN
# 2            NaN               NaN          NaN             NaN        NaN
# 3            NaN               NaN          NaN             NaN        NaN
# 4            NaN               NaN          NaN             NaN        NaN
#
#    free sulfur dioxide  total sulfur dioxide  density  pH  sulphates  alcohol  \
# 0                  NaN                   NaN      NaN NaN        NaN      NaN
# 1                  NaN                   NaN      NaN NaN        NaN      NaN
# 2                  NaN                   NaN      NaN NaN        NaN      NaN
# 3                  NaN                   NaN      NaN NaN        NaN      NaN
# 4                  NaN                   NaN      NaN NaN        NaN      NaN
#
#    quality
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
white["fixed acidity"] > 7
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# 4897    False
# Name: fixed acidity, Length: 4898, dtype: bool

# %%
white[white["fixed acidity"]>7]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# 5               8.1              0.28         0.40             6.9      0.050
# 9               8.1              0.22         0.43             1.5      0.044
# ...             ...               ...          ...             ...        ...
# 4808            7.3              0.35         0.67             8.3      0.053
# 4855            7.1              0.23         0.39            13.7      0.058
# 4856            7.1              0.23         0.39            13.7      0.058
# 4857            7.5              0.38         0.33             9.2      0.043
# 4875            7.4              0.22         0.26             1.2      0.035
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# 5                    30.0                  97.0  0.99510  3.26       0.44
# 9                    28.0                 129.0  0.99380  3.22       0.45
# ...                   ...                   ...      ...   ...        ...
# 4808                 10.0                 100.0  0.99590  3.19       0.50
# 4855                 26.0                 172.0  0.99755  2.90       0.46
# 4856                 26.0                 172.0  0.99755  2.90       0.46
# 4857                 19.0                 116.0  0.99444  3.08       0.42
# 4875                 18.0                  97.0  0.99245  3.12       0.41
#
#       alcohol  quality
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# 5        10.1        6
# 9        11.0        6
# ...       ...      ...
# 4808     10.9        5
# 4855      9.0        6
# 4856      9.0        6
# 4857     11.4        6
# 4875      9.7        6
#
# [1790 rows x 12 columns]

# %%
# white_filtered =  (white < (Q1 - 1.5 * IQR)) |(white > (Q3 + 1.5 * IQR))

Q1 = white.quantile(0.25)
Q3 = white.quantile(0.75)
IQR = Q3 - Q1
lower_q = Q1 - 1.5 * IQR
upper_q = Q3 + 1.5 * IQR
# print(IQR.round(2))
    
for i in white: 
    
    white_filtered = white.loc[(white[i] > lower_q) & (white[i] < upper_q)]
return df_filtered
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-207-4e18f168866c> in <module>
#      10 for i in white:
#      11
# ---> 12     white_filtered = white.loc[(white[i] > lower_q) & (white[i] < upper_q)]
#      13 return df_filtered
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
#     519
#     520         if isinstance(other, ABCSeries) and not self._indexed_same(other):
# --> 521             raise ValueError("Can only compare identically-labeled Series objects")
#     522
#     523         lvalues = extract_array(self, extract_numpy=True)
#
# ValueError: Can only compare identically-labeled Series objects

# %% [markdown]
# ## Multiple Regression Analysis

# %% [markdown]
# ### Scaling Transformation with QuantileTransformer
# -Non-linear tranformation that will help balance the indpedent variables' distribution
# -Useful in the presence of outliers

# %%
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import QuantileTransformer
from pandas import DataFrame as df
trans = QuantileTransformer(n_quantiles=3000, output_distribution='normal')
data = trans.fit_transform(white)
dataset = df(data)

# %%
#Visual confirmation that the distribution has been changed 
dataset.hist()
plt.show()

# %%
dataset
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.281588  0.087455  0.462279  2.829079  0.191736  0.631813  0.736400
# 1    -0.739693  0.429047  0.227622 -0.775328  0.565809 -1.382813 -0.052681
# 2     1.442896  0.213919  0.775328  0.233631  0.659612 -0.220765 -0.995610
# 3     0.461349 -0.474872  0.012956  0.511211  1.303519  0.735305  1.081609
# 4     0.461349 -0.474872  0.012956  0.511211  1.303519  0.735305  1.081609
# ...        ...       ...       ...       ...       ...       ...       ...
# 4893 -0.888774 -0.737497 -0.389510 -0.775328 -0.337272 -0.626210 -1.147721
# 4894 -0.260777  0.597485  0.462279  0.427672  0.379161  1.288997  0.692172
# 4895 -0.399448 -0.287681 -1.513931 -1.377397 -0.160749 -0.220765 -0.593992
# 4896 -1.803198  0.328879 -0.191736 -1.647933 -2.119937 -0.912598 -0.629773
# 4897 -1.099025 -0.737497  0.630283 -2.624817 -2.338916 -0.770258 -0.958562
#
#              7         8         9        10        11
# 0     2.696733 -1.300593 -0.294657 -1.820456  0.148907
# 1     0.069010  0.788946  0.137085 -0.613549  0.148907
# 2     0.348796  0.562379 -0.410789 -0.157364  0.148907
# 3     0.526032  0.066078 -0.758504 -0.301647  0.148907
# 4     0.526032  0.066078 -0.758504 -0.301647  0.148907
# ...        ...       ...       ...       ...       ...
# 4893 -0.913867  0.593992  0.245673  0.554564  0.148907
# 4894  0.308653 -0.224192 -0.200682 -0.503606 -0.892502
# 4895 -0.380958 -1.390464 -0.200682 -0.761293  0.148907
# 4896 -2.401309  1.019914 -1.018509  1.727778  1.142890
# 4897 -1.842920  0.562379 -1.888047  0.901877  0.148907
#
# [4898 rows x 12 columns]

# %% [markdown]
# ## MR: Scaling

# %%
X = white[white.columns[0:11]]
y = white["quality"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (4898, 11) (4898, 1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.2828919982151695
# Testing Score: 0.2727562934675569

# %% [markdown]
# Scaling input and target variables through the pipeline
# https://machinelearningmastery.com/how-to-transform-target-variables-for-regression-with-scikit-learn/
#
# - Input variable scaling is accounted for
# -Target scaling will be done through TransformedTargetRegressor
# - Incorperate QuantileTransformer?

# %%
#Transform input variables scale (features?)

from sklearn.preprocessing import QuantileTransformer

X = white[white.columns[0:11]]
qt = QuantileTransformer(n_quantiles=3000, random_state=42)
x_transformed = qt.fit_transform(X)

#does randomstate matter?

# %%
data = trans.fit_transform(data)
dataset = df(x_transformed)
dataset.hist()
plt.show()

# %%
from numpy import mean
from numpy import absolute
from numpy import loadtxt

from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LinearRegression

from sklearn.compose import TransformedTargetRegressor

from sklearn.preprocessing import QuantileTransformer

###split into inputs and outputs
# X, y = dataset[:, :-1], dataset[:, -1]

X = white[white.columns[0:11]]
y = white["quality"].values.reshape(-1, 1)


# transform input variables scales through pipeline
pipeline = Pipeline(steps=[('normalize', QuantileTransformer()), ('model', LinearRegression())])

# fit pipeline
pipeline.fit(train_x, train_y)

# make predictions
yhat = pipeline.predict(test_x)
pipeline = Pipeline(steps=[('power', PowerTransformer()), ('model', LinearRegression())])


# prepare the model with target scaling
model = TransformedTargetRegressor(regressor=pipeline, transformer=PowerTransformer())


# # evaluate model
# cv = KFold(n_splits=10, shuffle=True, random_state=1)
# scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# # convert scores to positive
# scores = absolute(scores)

# # summarize the result
# s_mean = mean(scores)
# print('Mean MAE: %.3f' % (s_mean))

# %% [markdown]
# # Principle Component Analysis (PCA)
#
# - Rerun when outliers are removed from dataset
# -Re-run with different scaling

# %%
from sklearn.decomposition import PCA

X
pca = PCA(n_components=10)
pc = pca.fit_transform(X)

print(X.shape)
print(pc.shape)
# Out:
# (4898, 11)
# (4898, 10)

# %%
pc_df = pd.DataFrame(pc)
pc_df = pd.concat([pc_df, white[['quality']]], axis = 1)
pc_df
# Out:
#               0          1          2         3         4         5         6  \
# 0     33.732754   1.238285  12.775292 -0.234922 -0.088245 -0.100476  0.014614
# 1    -11.925800 -18.957519  -3.857834 -1.249988 -0.858999  0.031639  0.025850
# 2    -41.224671   5.739874   2.466032 -0.953471  1.192391  0.171030 -0.030876
# 3     49.087353  -1.213107  -0.193184 -0.048469  0.254910 -0.011453 -0.058192
# 4     49.087353  -1.213107  -0.193184 -0.048469  0.254910 -0.011453 -0.058192
# ...         ...        ...        ...       ...       ...       ...       ...
# 4893 -47.882776   1.210830  -2.552092 -0.050523 -0.554207  0.034531  0.020207
# 4894  34.335895  13.158947  -0.167152 -0.551609 -0.266043 -0.066314 -0.008153
# 4895 -27.994223   1.986562  -3.766791 -1.742166 -0.496306 -0.222925 -0.074503
# 4896 -31.625623  -7.367985  -3.855849  1.805586 -1.072086 -0.027450 -0.005634
# 4897 -42.669090  -2.301131  -3.603838  0.578167 -0.682030 -0.066188  0.049350
#
#              7         8         9  quality
# 0     0.007957 -0.030343 -0.007354        6
# 1    -0.036137  0.033946 -0.007053        6
# 2    -0.081910  0.060987  0.005064        6
# 3    -0.093215 -0.066148  0.010212        6
# 4    -0.093215 -0.066148  0.010212        6
# ...        ...       ...       ...      ...
# 4893  0.001231 -0.051143 -0.001162        6
# 4894 -0.013244  0.060675 -0.007896        5
# 4895  0.092366 -0.070604 -0.013978        6
# 4896 -0.123184 -0.008553 -0.010527        7
# 4897 -0.186652 -0.036893 -0.018888        6
#
# [4898 rows x 11 columns]

# %%
pcX = pc_df[pc_df.columns[0:11]]
pcy = pc_df["quality"].values.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(pcX, pcy, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.metrics import mean_squared_error

prediction7 = model.predict(X_test_scaled)
rounded7 = np.rint(prediction7)

MSE = mean_squared_error(y_test, rounded7)
r2 = model.score(X_test_scaled, y_test)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.0, R2: 1.0

# %% [markdown]
# # Ordinal Regressions
# - I selected orginal regression because the target variable is ordinal, not continuous.
#
# - After trying three types of ordinal regressions (logistic, OrdinalRidge and LAD), logistic seems to be the strongest
#
# - Outliers weren't removed for these analysis
# - Used MinMaxScaling, but other scaling types may strengthen the model
#
# ** Double check negative values

# %% [markdown]
# Threshold-based model (LogisticIT)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
import mord as m
classifier = m.LogisticIT()

# %%
classifier.fit(X_train_scaled, y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticIT(alpha=1.0, max_iter=1000, verbose=0)

# %%
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.5303566566839096
# Testing Data Score: 0.5208163265306123

# %% [markdown]
# Regression based model
#
# -Ordinal Ridge

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
import mord as m
classifier = m.OrdinalRidge()
classifier.fit(X_train_scaled, y_train)
# Out:
# OrdinalRidge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#              normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: -0.6425265450585352
# Testing Data Score: -0.6653061224489796

# %% [markdown]
# Regression based model
#
# - LAD :
# The Least Absolute Deviation model instead minimizes the absolute value of the residuals, i.e.MAE regression
#
# This provides a more robust solution when outliers are present, but it does have some undesirable properties, most notably that there are some situations where there is no unique solution, and in fact an infinite number of different regression lines are possible.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
import mord as m
classifier = m.LAD()
classifier.fit(X_train_scaled, y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LAD(C=1.0, dual=True, epsilon=0.0, fit_intercept=True, intercept_scaling=1.0,
#     loss='epsilon_insensitive', max_iter=1000, random_state=None, tol=0.0001,
#     verbose=0)

# %%
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: -0.5246392594609312
# Testing Data Score: -0.5591836734693878
